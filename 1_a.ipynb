# %%
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as sn
import matplotlib.pylab as plt
import colorsys

# opening the image and converting it to grayscale
a1 = iio.imread('exercise/baby.jpeg')
a2 = iio.imread('exercise/balloons_noisy.png')
a3 = iio.imread('exercise/flower.jpeg')

# initializing the filter of size 5 by 5
# the filter is divided by 25 for normalization
k = np.ones((5, 5)) / 25

# performing convolution
if a1.ndim ==3:
    b1 = np.zeros_like(a1)
    for c in range(3):
        b1[:,:,c] = sn.convolve(a1[:,:,c], k).astype(np.uint8)
else:
    b1 = sn.convolve(a1, k).astype(np.uint8)

if a2.ndim ==3:
    b2 = np.zeros_like(a2)
    for c in range(3):
        b2[:,:,c] = sn.convolve(a2[:,:,c], k).astype(np.uint8)
else:
    b2 = sn.convolve(a2, k).astype(np.uint8)

if a3.ndim ==3:
    b3 = np.zeros_like(a3)
    for c in range(3):
        b3[:,:,c] = sn.convolve(a3[:,:,c], k).astype(np.uint8)
else:
    b3 = sn.convolve(a3, k).astype(np.uint8)

iio.imsave('baby_mean_filter.jpeg', b1)
iio.imsave('balloons_noisy_mean_filter.png', b2)
iio.imsave('flower_mean_filter.jpeg', b3)

plt.subplot(1,3,1)
plt.imshow(b1)
plt.title("Baby (mean)")


plt.subplot(1,3,2)
plt.imshow(b2)
plt.title("Balloons (mean)")


plt.subplot(1,3,3)
plt.imshow(b3)
plt.title("Flower (mean)")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as sn
import matplotlib.pylab as plt
import colorsys


# opening the image and converting it to grayscale
a = iio.imread('exercise/baby.jpeg').astype(np.uint8)
a2 = iio.imread('exercise/flower.jpeg').astype(np.uint8)
a3 = iio.imread('exercise/balloons_noisy.png').astype(np.uint8)

b = sn.median_filter(a, size=5, footprint=None, output=None,
                     mode='reflect', cval=0.0, origin=0)
b2 = sn.median_filter(a2, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)
b3 = sn.median_filter(a3, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)

iio.imsave('baby_median_filter.png', b)
iio.imsave('balloons_noisy_median_filter.png', b2)
iio.imsave('flower_median_filter.jpeg', b3)

plt.subplot(1,3,1)
plt.imshow(b1)
plt.title("Baby (median)")


plt.subplot(1,3,2)
plt.imshow(b2)
plt.title("Flower (median)")


plt.subplot(1,3,3)
plt.imshow(b3)
plt.title("Balloons (median)")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as sn
import matplotlib.pylab as plt
import colorsys

a = iio.imread('exercise/baby.jpeg').astype(np.uint8)
a2 = iio.imread('exercise/flower.jpeg').astype(np.uint8)
a3 = iio.imread('exercise/balloons_noisy.png').astype(np.uint8)

b = sn.maximum_filter(a, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)
b2 = sn.maximum_filter(a2, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)
b3 = sn.maximum_filter(a3, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)


iio.imsave('baby_max_filter.png', b)
iio.imsave('balloons_noisy_max_filter.png', b2)
iio.imsave('flower_max_filter.jpeg', b3)

plt.subplot(1,3,1)
plt.imshow(b1)
plt.title("Baby (max)")


plt.subplot(1,3,2)
plt.imshow(b2)
plt.title("Flower (max)")


plt.subplot(1,3,3)
plt.imshow(b3)
plt.title("Balloons (max)")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import imageio.v2 as iio
import scipy.ndimage as sn
import matplotlib.pylab as plt
import colorsys


a = iio.imread('exercise/baby.jpeg').astype(np.uint8)
a2 = iio.imread('exercise/flower.jpeg').astype(np.uint8)
a3 = iio.imread('exercise/balloons_noisy.png').astype(np.uint8)

b = sn.minimum_filter(a, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)
b2 = sn.minimum_filter(a2, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)
b3 = sn.minimum_filter(a3, size=5, footprint=None, output=None,
                      mode='reflect', cval=0.0, origin=0)

iio.imsave('baby_min_filter.png', b)
iio.imsave('balloons_noisy_min_filter.png', b2)
iio.imsave('flower_min_filter.jpeg', b3)

plt.subplot(1,3,1)
plt.imshow(b1)
plt.title("Baby (min)")


plt.subplot(1,3,2)
plt.imshow(b2)
plt.title("Flower (min)")


plt.subplot(1,3,3)
plt.imshow(b3)
plt.title("Balloons (min)")

plt.tight_layout()
plt.show()
